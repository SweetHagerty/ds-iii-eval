# %% [markdown]
# <a href="https://colab.research.google.com/github/SweetHagerty/ds-iii-eval/blob/main/DS_III_Pair_Programming_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SweetHagerty/ds-iii-eval.git /content/interview
# Out:
# Cloning into '/content/interview'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 24.05 KiB | 12.02 MiB/s, done.
